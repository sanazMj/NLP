# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
Main_dir = '/content/drive/MyDrive/NLP/GAN_for_text_generation/'
Data_dir = '/content/drive/MyDrive/NLP/GAN_for_text_generation/Software_engineering_Datasets/SentimentAnalysis/'
Data_dir_replication = '/replication/dataset/'

# %%
Data_files = ['oracle.xlsx', 'BenchmarkUddinSO-ConsoliatedAspectSentiment.xls', 'github_gold.csv','AppReviews.csv', 'JIRA.csv', 'StackOverflow.csv']

# %%
import os
os.chdir(Main_dir)
# !pwd
# Out:
# /content/drive/MyDrive/NLP/GAN_for_text_generation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Load Data Code Reviews (CR)

# %%
# Load the xlsx file
excel_data = pd.read_excel(Data_dir + Data_files[0], header=None, names=['Doc', 'Label'] )
excel_data.shape
# Out:
# (1600, 2)

# %%
excel_data['Label'].value_counts() # 0 (Non-negative), -1 (Negative)
# Out:
#  0    1202
# -1     398
# Name: Label, dtype: int64

# %% [markdown]
# # Load Data API Reviews

# %%
# !pip install xlrd==1.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 103 kB 9.4 MB/s
# ...
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# ...

# %%
# Load the xls file
excel_data = pd.read_excel(Data_dir + Data_files[1],engine='xlrd' )
excel_data.shape
# Out:
# (4522, 9)

# %%
excel_data.head()
# Out:
#      thread         tid                                               sent  \
# 0  15936368  15936368:1  "JAXB Bindings File Sets @XmlElement type to S...
# 1  15936368  15936368:2  "I'm trying to create an CODETERM1 that takes ...
# 2  15936368  15936368:3  "The purpose is simlply to remove timezone dat...
# 3  15936368  15936368:4          "It looks like this: CODESNIPPET_JAVA1 ."
# 4  15936368  15936368:5  "This works fine for the following code: CODES...
#
#   ManualLabel                codes stakeholder signal intent action
# 0           o      ["'Usability'"]         NaN   used    NaN    NaN
# 1           o         ["'Others'"]         NaN   used    NaN    NaN
# 2           o         ["'Others'"]         NaN   used    NaN    NaN
# 3           o         ["'Others'"]         NaN   used    NaN    NaN
# 4           p  ["'OnlySentiment'"]         NaN   used    NaN    NaN

# %%
excel_data['ManualLabel'].value_counts() # 0 (Non-negative), -1 (Negative)
# Out:
# o    2635
# p    1048
# n     839
# Name: ManualLabel, dtype: int64

# %% [markdown]
# # Load Data Github

# %% [markdown]
# # Load Data StackOverflow

# %%
excel_data = pd.read_csv(Data_dir + Data_dir_replication  + Data_files[-1])
excel_data.shape
# Out:
# (1500, 3)

# %%
excel_data['oracle'].value_counts() # 1 positive, 0 neutral, -1 negative
# Out:
#  0    1191
# -1     178
#  1     131
# Name: oracle, dtype: int64

# %% [markdown]
# # Load Data JIRA

# %%
excel_data = pd.read_csv(Data_dir + Data_dir_replication  + Data_files[-2])
excel_data.shape
# Out:
# (926, 2)

# %%
excel_data['oracle'].value_counts() # 1 positive, -1 negative
# Out:
# -1    636
#  1    290
# Name: oracle, dtype: int64

# %% [markdown]
# # Load Data App Reviews

# %%
excel_data = pd.read_csv(Data_dir + Data_dir_replication  + Data_files[-3])
excel_data.shape
# Out:
# (341, 2)

# %%
excel_data['oracle'].value_counts() # 1 positive, 0 neutral, -1 negative
# Out:
#  1    186
# -1    130
#  0     25
# Name: oracle, dtype: int64
